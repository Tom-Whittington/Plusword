# %%
import time
import pandas as pd
from bs4 import BeautifulSoup
import requests
from concurrent.futures import ThreadPoolExecutor
import itertools
from time import sleep

# %%
# html class of original post from the thread
original_post_class = 'p-4 pb-1 pt-2.5 lg:py-2.5 mt-2.5 lg:mt-1.5 border-t border-b sm:border sm:rounded ' \
                   'border-mumsnet-forest-border bg-mumsnet-forest dark:bg-mumsnet-forest-dark'

# html class of a normal post from the thread
normal_post_class = 'lg:py-2.5 pt-2.5 pb-1 p-4 border-t border-b sm:border sm:rounded mt-1.5 overflow-x-hidden ' \
                     'bg-white dark:bg-gray-800 border-gray-200'

# html class of a post from the thread creator
original_poster_reply_class = 'lg:py-2.5 pt-2.5 pb-1 p-4 border-t border-b sm:border sm:rounded mt-1.5 ' \
                              'overflow-x-hidden bg-mumsnet-forest dark:bg-mumsnet-forest-dark ' \
                              'border-mumsnet-forest-border'

# %%
def url_generator():
    
    thread_list = [
    'https://www.mumsnet.com/talk/am_i_being_unreasonable/4676538-if-you-like-wordle-plusword-is-even-better-thread-4?page=',
    #'https://www.mumsnet.com/talk/_chat/4714295-plusword-new-thread-1?page=',
    #'https://www.mumsnet.com/talk/_chat/4765702-plusword-new-thread-2?page='
    ]

    url_list=[]

    for thread in thread_list:
        for page_number in range(1,11):
            url = thread + str(page_number)
            url_list.append(url)
        
    return url_list

# %%
def multithread_scraper(url):
    
    #gets web pages
    with requests.get(url, allow_redirects=False) as r:
        
        # returns None if url redirects you to main page
        # happens if page number is higher than current page count
        if r.status_code != 302:

            soup = BeautifulSoup(r.content, features="html5lib")

            post_list=[]
            
            # selects first page as we need original post
            if url[-2:] == '=1':

                original_post_list = []

                # selects post info and body and drops title and other stuff we dont need
                original_post = soup.find('div', class_=original_post_class)
                original_post = original_post.find_all('div', class_='')[2].find_all('p')
                
                paragraph_list = []
                for paragraph in original_post:
                    post_text = paragraph.getText().split()
                    post_text = ' '.join(post_text)
                    paragraph_list.append(post_text)

                meta_data = paragraph_list[0].split()
                del meta_data[1]
                meta_data.append(paragraph_list[1])
                original_post = meta_data
                original_post_list.append(original_post)
                
                #flattens list
                original_post = [val for sublist in original_post_list for val in sublist]

                return(original_post)

            else:
                whole_post_list = []
                posts = soup.find_all('div', class_=[normal_post_class, original_poster_reply_class])
                
                # deletes body of op which is scraped again
                del posts[0]

                for post in posts:
                    post_text = post.getText().split()
                    
                    #separates out meta data and post body
                    meta_data = post_text[:4]
                    post_body = post_text[4:]

                    #removes fullstop from meta data
                    meta_data.pop(1)

                    #converts whole of post body to one string
                    post_body = ' '.join(post_body)
                    meta_data.append(post_body)
                    whole_post = meta_data
                    
                    whole_post_list.append(whole_post)
                    #whole_post = [val for sublist in whole_post for val in sublist]
                    
                


                return(whole_post_list)

        return

# %%
modified_start = time.time()
result_list=[]
url_list = url_generator()

# Runs scraper 
with ThreadPoolExecutor() as executor:
    results = executor.map(multithread_scraper, url_list)
    for result in results:
        if result != None:
            result_list.append(result)
result_list = [val for sublist in result_list for val in sublist]     
result_list = [result_list]
result_list
# Out:
# [['ILoveAllRainbowsx',
#   '13/11/2022',
#   '14:18',
#   'Previous thread: www.mumsnet.com/talk/am_i_being_unreasonable/4633689-if-you-like-wordle-plusword-is-even-better-thread-3?page=10&reply=121497607',
#   ['oviraptor21',
#    '15/11/2022',
#    '07:29',
#    '⏱️ I just completed PlusWord in 08:36 www.telegraph.co.uk/plusword/ Some rather misleading clueing. Add message Save Share Report Bookmark'],
#   ['DadDadDad',
#    '15/11/2022',
#    '07:31',
#    "A lot tougher today. I was determined not to look anything up, and eventually deduced the whole grid - it was just 6A I hadn't heard of, but I agree that the 1D clue feels a bit off. At least the PW was easy. 10:39 for me! Add message Save Share Report Bookmark"],
#   ['JoyDivisionOvenGlovesx',
#    '15/11/2022',
#    '07:47',
#    '⏱️ I just completed PlusWord in 02:19 Nah, not liking that one. Guess work galore and definitely a 🤔clue. Add message Save Share Report Bookmark'],
#   ['UmbilicusProfundus',
#    '15/11/2022',
#    '08:04',
#    '⏱️ I just completed PlusWord in 02:54 Had to keep guessing for the 1D 6A intersection but got there in the end. Add message Save Share Report Bookmark'],
#   ['Readytostartagain',
#    '15/11/2022',
#    '08:05',
#    '⏱️ I just completed PlusWord in 03:00 1D just came out of the other answers but definitely harder today Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '15/11/2022',
#    '09:04',
#    'I did actually know the blanket one. But had to cheat on the others. I had the wrong (but very similar) answer to 8A so couldn’t figure out 2D. Annoying! Add message Save Share Report Bookmark'],
#   ['AngeloMysterioso',
#    '15/11/2022',
#    '09:15',
#    'Todays is ridiculous… the only answers I’m certain of are 4D/7A and I haven’t a clue about 6A Add message Save Share Report Bookmark'],
#   ['Floralnomad',
#    '15/11/2022',
#    '10:11',
#    '02:22 that CW was a mix of simple and difficult . Add message Save Share Report Bookmark'],
#   ['Sunbird24',
#    '15/11/2022',
#    '14:14',
#    '⏱️ I just completed PlusWord in 02:16 Yup, me too! Add message Save Share Report Bookmark'],
#   ['SerotinaPickeler',
#    '15/11/2022',
#    '16:34',
#    "Just discovered Plusword thanks to this thread. Completed in 31 minutes 😂. Should improve on that now I actually know what I'm doing. Thanks for the heads up (although some of your times are quite intimidating) Add message Save Share Report Bookmark"],
#   ['TwinklingStarlight',
#    '15/11/2022',
#    '16:40',
#    "@SerotinaPickeler it's freakishly hard today. I'm stuck and popping on here to see if it's just me. Add message Save Share Report Bookmark"],
#   ['MarmiteWine',
#    '15/11/2022',
#    '18:31',
#    '⏱️ I just completed PlusWord in 08:46 www.telegraph.co.uk/plusword/ My worst time ever by about 5 minutes! Sorry @oviraptor21 but I was pleased see I had some company! Add message Save Share Report Bookmark'],
#   ['oviraptor21',
#    '15/11/2022',
#    '19:05',
#    "Pleased to know I'm in such exalted company 😂 Add message Save Share Report Bookmark"],
#   ['BrilliantGreenFlamingo',
#    '15/11/2022',
#    '19:51',
#    '@SerotinaPickeler just don’t look at sunbird’s times… Add message Save Share Report Bookmark'],
#   ['Hepzibar',
#    '15/11/2022',
#    '20:29',
#    "@SerotinaPickeler I'm pretty new here and I didn't post some of my times at the start. I felt as thick as a plank. But I have improved and got under 2 minutes (once). 😊 Add message Save Share Report Bookmark"],
#   ['Drywhitefruitycidergin',
#    '15/11/2022',
#    '20:44',
#    "I gave up and googled - I don't think I'd have ever finished it otherwise.... Hoping tomorrow's will be a bit better. Add message Save Share Report Bookmark"],
#   ['Sunbird24',
#    '15/11/2022',
#    '20:54',
#    'Today’s was definitely a stinker, hope tomorrow’s is back to normal! Add message Save Share Report Bookmark'],
#   ['Hepzibar',
#    '16/11/2022',
#    '06:36',
#    'This is awful. Had to look up some. 1D is another WTF and as for the PW- no idea. This is supposed to be fun! 😂 Add message Save Share Report Bookmark'],
#   ['DadDadDad',
#    '16/11/2022',
#    '07:38',
#    'Sunbird24 · 15/11/2022 20:54 Today’s was definitely a stinker, hope tomorrow’s is back to normal! Nope Add message Save Share Report Bookmark'],
#   ['JoyDivisionOvenGlovesx',
#    '16/11/2022',
#    '07:44',
#    '⏱️ I just completed PlusWord in 03:01 Someone has pissed off that compiler. Or they’re on this thread, saw Sunbird’s times, and thought “nah, not having that…” Add message Save Share Report Bookmark'],
#   ['DadDadDad',
#    '16/11/2022',
#    '07:54',
#    "I'm not even going to record my time today. After 10 minutes, I'd ground to a halt, beginning to suspect that the obvious answer I'd put for 1D wasn't right, and resorted to Google. 1D (with that sense), 6A, 2D weren't in my brain! And 3D I'm not sure about either. Add message Save Share Report Bookmark"],
#   ['LavenderfortheBees',
#    '16/11/2022',
#    '08:02',
#    "I had to cheat today and can usually do it in less than 2 minutes. How crap. The answers for some of them didn't really work. Add message Save Share Report Bookmark"],
#   ['sanityisamyth',
#    '16/11/2022',
#    '08:12',
#    'Found today and yesterday really hard. Gave up yesterday and today took over 8 minutes with some Googling. Add message Save Share Report Bookmark'],
#   ['DadDadDad',
#    '16/11/2022',
#    '08:51',
#    "Has today's defeated @Sunbird24 ?! Add message Save Share Report Bookmark"],
#   ['AngeloMysterioso',
#    '16/11/2022',
#    '08:57',
#    'I think I’ve done the CW right but I have no idea whatsoever for the PW. Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '16/11/2022',
#    '09:23',
#    'Uh oh. Gonna looks at it now. You guys have made me think it will be impossible. Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '16/11/2022',
#    '09:32',
#    'Yeah, too hard. Add message Save Share Report Bookmark'],
#   ['Y7drama',
#    '16/11/2022',
#    '09:34',
#    'Today’s was impossible. Had to Google most of it! Add message Save Share Report Bookmark'],
#   ['Mumsnut',
#    '16/11/2022',
#    '09:52',
#    'Yep. 12.15 with much googling Add message Save Share Report Bookmark'],
#   ['MarmiteWine',
#    '16/11/2022',
#    '10:06',
#    "oviraptor21 · 15/11/2022 19:05 Pleased to know I'm in such exalted company 😂 😂😂😂 Add message Save Share Report Bookmark"],
#   ['MarmiteWine',
#    '16/11/2022',
#    '10:13',
#    "⏱️ I just completed PlusWord in 03:52 www.telegraph.co.uk/plusword/ Several wrong directions! Thank goodness for 6A, which was the only one I was sure about, then 4D. Got the first letter of 3D, which gave me a good idea then of what 1A was going to be. It took a leap of faith to allow 2D to develop from there as it was a new word to me. Got the PW straightaway, but it's a word I'm familiar with. Add message Save Share Report Bookmark"],
#   ['Sunbird24',
#    '16/11/2022',
#    '10:32',
#    '⏱️ I just completed PlusWord in 03:03 I’m back at work now after some time off so will probably be posting at different times than you’re used to seeing me! This is I think my worst time? Cross with 1D, didn’t know 2D, but got the PW straight away as I know one… 😊 Add message Save Share Report Bookmark'],
#   ['Floralnomad',
#    '16/11/2022',
#    '10:36',
#    'I just completed PlusWord in 01:48 , I finished the CW at 01:08 and the PW was a word that was quite familiar to me . Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '16/11/2022',
#    '10:38',
#    'Wow, floral. I’m totally stuck despite googling. Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '16/11/2022',
#    '10:46',
#    'Can someone PM me 7A and 5D? Thanks Add message Save Share Report Bookmark'],
#   ['MarmiteWine',
#    '16/11/2022',
#    '10:58',
#    "I've sent a PM @BrilliantGreenFlamingo Add message Save Share Report Bookmark"],
#   ['BrilliantGreenFlamingo',
#    '16/11/2022',
#    '11:05',
#    'With the help of Google, marmitewine and some random inputting of letters in the PW, I got there. In 14 mins. Add message Save Share Report Bookmark'],
#   ['UmbilicusProfundus',
#    '16/11/2022',
#    '11:07',
#    '10 minutes something, but no googling! Add message Save Share Report Bookmark'],
#   ['AngeloMysterioso',
#    '16/11/2022',
#    '14:00',
#    'Well I got it, but thrown by the PW being the type of word it is… didn’t think they got used in word puzzles? ⏱️ I just completed PlusWord in 09:17 Add message Save Share Report Bookmark'],
#   ['TwinklingStarlight',
#    '16/11/2022',
#    '14:05',
#    "@AngeloMysterioso it's not just that sort of word. Add message Save Share Report Bookmark"],
#   ['BrilliantGreenFlamingo',
#    '16/11/2022',
#    '17:03',
#    'Same, angelo. Didn’t know it was they type of word that is allowed. I was just putting in random letters by that point Add message Save Share Report Bookmark'],
#   ['LikeTearsInRain',
#    '17/11/2022',
#    '00:29',
#    'Couldn’t do yesterdays without a load of help. This one was tricky too but managed it without. One word just came together from the others, I still don’t get the clue… ⏱️ I just completed PlusWord in 04:57 Add message Save Share Report Bookmark'],
#   ['Floralnomad',
#    '17/11/2022',
#    '00:49',
#    '2:51 today , not sure why it took so long Add message Save Share Report Bookmark'],
#   ['JoyDivisionOvenGlovesx',
#    '17/11/2022',
#    '06:04',
#    '⏱️ I just completed PlusWord in 01:52 Better than yesterday, but still hmmmm. Add message Save Share Report Bookmark'],
#   ['Hepzibar',
#    '17/11/2022',
#    '06:49',
#    'Common flower? Common to who? Never heard of 5D and 7A what the actual...? And the PW - just kept rearranging letters! Pah! ⏱️ I just completed PlusWord in 05:31 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark'],
#   ['DadDadDad',
#    '17/11/2022',
#    '07:28',
#    'Not as tough as yesterday, but still some challenges. Did it in 4:04. Only after completing did the penny drop on the meaning of 7A. Add message Save Share Report Bookmark'],
#   ['UmbilicusProfundus',
#    '17/11/2022',
#    '08:01',
#    '⏱️ I just completed PlusWord in 02:27 Like @Drywhitefruitycidergin I thought I was on for a quick time but was then hit by the (new normal?) reality Add message Save Share Report Bookmark'],
#   ['Readytostartagain',
#    '17/11/2022',
#    '08:11',
#    '⏱️ I just completed PlusWord in 03:16 A bit of guessing but PW was straightforward at least Add message Save Share Report Bookmark'],
#   ['UmbilicusProfundus',
#    '17/11/2022',
#    '08:54',
#    'BTW I quite like it being more of a challenge - a challenge to complete rather than just race through an easy one to get the quickest time. But the clues have to be fair/accurate , even if a bit obscure or verging on cryptic. Add message Save Share Report Bookmark'],
#   ['restisall',
#    '17/11/2022',
#    '09:46',
#    'DadDadDad · 17/11/2022 07:28 Not as tough as yesterday, but still some challenges. Did it in 4:04. Only after completing did the penny drop on the meaning of 7A. Still baffled by the meaning of 7A! Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '17/11/2022',
#    '10:03',
#    '7:18. Don’t get 7A at all. And I wasn’t sure the PW was a word but apparently it is! Don’t know what it means tho. Add message Save Share Report Bookmark'],
#   ['DadDadDad',
#    '17/11/2022',
#    '10:03',
#    '@restisall - if you type "bye" plus the answer into Google into should bring up the meaning that you might not have thought of. Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '17/11/2022',
#    '10:13',
#    'Well I defo would not have guessed that. I didn’t know it meant that too. Add message Save Share Report Bookmark'],
#   ['MarmiteWine',
#    '17/11/2022',
#    '10:55',
#    '⏱️ I just completed PlusWord in 03:48 www.telegraph.co.uk/plusword/ Should have been at least 30 seconds faster, but I somehow forgot how the yellow letters work, so convinced myself that the 2 yellow letters in 2D had to be the same letter. That was an interesting diversion 😂 Knew the PW though. Add message Save Share Report Bookmark'],
#   ['Sunbird24',
#    '17/11/2022',
#    '15:13',
#    'Um… Reckon they’ve banned me? Add message Save Share Report Bookmark'],
#   ['Swissnotswiss',
#    '17/11/2022',
#    '15:22',
#    'I got the same message @Sunbird24 Add message Save Share Report Bookmark'],
#   ['Sunbird24',
#    '17/11/2022',
#    '16:17',
#    '@Swissnotswiss they don’t want us doing their puzzle… 🤷🏻\u200d♀️ Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '17/11/2022',
#    '16:26',
#    'What’s that mean?! Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '17/11/2022',
#    '16:26',
#    'I’ve got it too now I’ve refreshed the page Add message Save Share Report Bookmark'],
#   ['Drywhitefruitycidergin',
#    '17/11/2022',
#    '17:05',
#    "I've got it too but it works on secret mode 🤷\u200d♀️ Add message Save Share Report Bookmark"],
#   ['Sunbird24',
#    '17/11/2022',
#    '17:14',
#    '⏱️ I just completed PlusWord in 01:31 Ugh, had to go and do it in private mode - thanks for suggesting that @Drywhitefruitycidergin! Add message Save Share Report Bookmark'],
#   ['hoochyhag',
#    '17/11/2022',
#    '17:38',
#    'Oh no! Another addictive wordgame 🤪 Add message Save Share Report Bookmark'],
#   ['hoochyhag',
#    '17/11/2022',
#    '17:40',
#    'Only took me 18m and 34 seconds 😂 Add message Save Share Report Bookmark'],
#   ['oviraptor21',
#    '17/11/2022',
#    '18:15',
#    'Seems I do OK relatively speaking although had no clue for 5d. ⏱️ I just completed PlusWord in 01:48 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark'],
#   ['oviraptor21',
#    '17/11/2022',
#    '18:15',
#    'I did 🙄 Add message Save Share Report Bookmark'],
#   ['sanityisamyth',
#    '17/11/2022',
#    '18:59',
#    "I can't get into it today. I get the same as the screenshot. Refreshing doesn't help! Add message Save Share Report Bookmark"],
#   ['Sunbird24',
#    '17/11/2022',
#    '19:10',
#    '@sanityisamyth do you have a secret/private browsing mode? That’s the only way I got to it Add message Save Share Report Bookmark'],
#   ['Usernamenotavailabletryanother',
#    '17/11/2022',
#    '21:28',
#    'I can’t get on even on private mode 😞 it asks me if I want a free trial… so I’m guessing we have to subscribe to play it now? Add message Save Share Report Bookmark'],
#   ['Sunbird24',
#    '18/11/2022',
#    '00:36',
#    '⏱️ I just completed PlusWord in 01:11 Better than the last couple of days! I had some typing issues so expecting some faster times. Still had to do it in private mode though… Add message Save Share Report Bookmark'],
#   ['bruffin',
#    '18/11/2022',
#    '01:30',
#    'This has been deleted by MNHQ for breaking our Talk Guidelines. I keep getting that message. I find if i use the links on here it works fine Add message Save Share Report Bookmark'],
#   ['Floralnomad',
#    '18/11/2022',
#    '01:35',
#    '01:41 with a few typos , I couldn’t get to it via the links here Add message Save Share Report Bookmark'],
#   ['Whitegrenache',
#    '18/11/2022',
#    '01:49',
#    "I couldn't access it either! I'll try again now Add message Save Share Report Bookmark"],
#   ['sneezums',
#    '18/11/2022',
#    '01:49',
#    '1.05 here Add message Save Share Report Bookmark'],
#   ['Whitegrenache',
#    '18/11/2022',
#    '01:50',
#    'Nope Got the same error message as Pp Does this mean I have to pay?! Add message Save Share Report Bookmark'],
#   ['Whitegrenache',
#    '18/11/2022',
#    '01:51',
#    'Oh the link works!! How strange Add message Save Share Report Bookmark'],
#   ['BessieSurtees',
#    '18/11/2022',
#    '05:48',
#    'I had to use private mode today. Thanks for the tip. Add message Save Share Report Bookmark'],
#   ['JoyDivisionOvenGlovesx',
#    '18/11/2022',
#    '06:27',
#    '⏱️ I just completed PlusWord in 01:06 Back to bring ok-ish. I keep tab open and refresh each morning, worked ok for me today. Add message Save Share Report Bookmark'],
#   ['oviraptor21',
#    '18/11/2022',
#    '07:27',
#    '⏱️ I just completed PlusWord in 01:10 www.telegraph.co.uk/plusword/ The usual typos but grateful for the break after a few days of tussles. Add message Save Share Report Bookmark'],
#   ['Welshwabbit',
#    '18/11/2022',
#    '07:31',
#    "I can't get in, keep getting the error message. Add message Save Share Report Bookmark"],
#   ['BrilliantGreenFlamingo',
#    '18/11/2022',
#    '07:35',
#    'I’ve still got error message Add message Save Share Report Bookmark'],
#   ['Whatafool123',
#    '18/11/2022',
#    '07:39',
#    'Me too! Has the link changed? No sign of a request to pay. Add message Save Share Report Bookmark'],
#   ['UmbilicusProfundus',
#    '18/11/2022',
#    '07:54',
#    'Yep could only get in via incognito mode in chrome. 1:05 today, but it felt quicker/easier. I suspect incognito mode bends time somehow. Add message Save Share Report Bookmark'],
#   ['Readytostartagain',
#    '18/11/2022',
#    '08:16',
#    '1:07 for me. Hot in with no issues via safari Add message Save Share Report Bookmark'],
#   ['DadDadDad',
#    '18/11/2022',
#    '08:30',
#    '1:38. A lot more straightforward today. Add message Save Share Report Bookmark'],
#   ['Drywhitefruitycidergin',
#    '18/11/2022',
#    '08:42',
#    '⏱️ I just completed PlusWord in 01:54 www.telegraph.co.uk/plusword/ Had to go in on secret mode. It was actually about 4 minutes but I stopped and then dd2 closed my tab when she did wordle! Much nicer today 😀 Add message Save Share Report Bookmark'],
#   ['starfishmummy',
#    '18/11/2022',
#    '08:45',
#    'I got in using my phones browser (samsung) rather than chrome Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '18/11/2022',
#    '09:01',
#    'How can I get in? I’m on safari Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '18/11/2022',
#    '09:21',
#    'Thanks! I’m in. Can’t bloody do it tho. Ha Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '18/11/2022',
#    '09:27',
#    '2:56 in the end. What does clearing cookies do? Add message Save Share Report Bookmark'],
#   ['MarmiteWine',
#    '18/11/2022',
#    '09:38',
#    "⏱️ I just completed PlusWord in 00:50 www.telegraph.co.uk/plusword/ Used a different browser. Frustrated today because this could have been a faster time. I'm on holiday and the WiFi keeps dipping in and out. Add message Save Share Report Bookmark"],
#   ['SerotinaPickeler',
#    '18/11/2022',
#    '12:20',
#    "I think I've got the crossword clues right but don't understand the point of the plusword Other than using the highlighted letters from the grid it seems to expect random other letters not in the grid? Seems a bit pointless? Add message Save Share Report Bookmark"],
#   ['Sunbird24',
#    '18/11/2022',
#    '13:45',
#    'My page has gone back to normal now… Add message Save Share Report Bookmark'],
#   ['bruffin',
#    '18/11/2022',
#    '15:32',
#    "SerotinaPickeler · 18/11/2022 12:20 I think I've got the crossword clues right but don't understand the point of the plusword Other than using the highlighted letters from the grid it seems to expect random other letters not in the grid? Seems a bit pointless? i dont think it's pointless, just makes it a bit more difficult Add message Save Share Report Bookmark"],
#   ['Hepzibar',
#    '18/11/2022',
#    '21:46',
#    "Late today and tired (that's my excuse) ⏱️ I just completed PlusWord in 02:52 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark"],
#   ['Hepzibar',
#    '19/11/2022',
#    '08:22',
#    'Back to mornings. Struggled with PW ⏱️ I just completed PlusWord in 03:00 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark'],
#   ['Sunbird24',
#    '19/11/2022',
#    '08:30',
#    '⏱️ I just completed PlusWord in 01:05 We’ve definitely had worse weekends! I think 3D was a horrible clue though… Add message Save Share Report Bookmark'],
#   ['oviraptor21',
#    '19/11/2022',
#    '08:46',
#    "⏱️ I just completed PlusWord in 03:39 www.telegraph.co.uk/plusword/ I wasn't thinking along the right lines for 1a which really didn't help. Add message Save Share Report Bookmark"],
#   ['Readytostartagain',
#    '19/11/2022',
#    '08:51',
#    '3:46 for me today found that quite hard Add message Save Share Report Bookmark'],
#   ['JoyDivisionOvenGlovesx',
#    '19/11/2022',
#    '09:36',
#    '⏱️ I just completed PlusWord in 01:01 Found that broadly fine, with notable exception of 3D. Add message Save Share Report Bookmark'],
#   ['MarmiteWine',
#    '19/11/2022',
#    '10:46',
#    '⏱️ I just completed PlusWord in 01:46 www.telegraph.co.uk/plusword/ Who knew there were so many possible answers for 1A? I suspect I had the same thinking as @oviraptor21 (and likely others too). Agree about 3D also! Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '19/11/2022',
#    '10:53',
#    'I’m totally stuck Add message Save Share Report Bookmark'],
#   ['Floralnomad',
#    '19/11/2022',
#    '11:03',
#    'A slow 02:55 for me , changed the ex PM about 5 times and struggled with the PW - I do like at least one anchor letter to work with . Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '19/11/2022',
#    '11:04',
#    'I’m on 13 mins and only have three answers. Keep deleting all my answers coz I’m not sure about them. Add message Save Share Report Bookmark'],
#   ['Drywhitefruitycidergin',
#    '19/11/2022',
#    '11:23',
#    '⏱️ I just completed PlusWord in 15:30 www.telegraph.co.uk/plusword/ I went through 3 PMs before I got here! Add message Save Share Report Bookmark'],
#   ['MarmiteWine',
#    '19/11/2022',
#    '11:24',
#    "BrilliantGreenFlamingo · 19/11/2022 11:04 I’m on 13 mins and only have three answers. Keep deleting all my answers coz I’m not sure about them. @BrilliantGreenFlamingo I'm online if you want to PM me for help/reassurance Add message Save Share Report Bookmark"],
#   ['DadDadDad',
#    '19/11/2022',
#    '11:42',
#    "I found today's a stinker, and resorted to tools on Google to help me. Wrote down every 5-letter surname in the list of UK Prime Ministers (I made it seven of them) before I realised what was going to work. No point recording a time when I've been thinking about it off and on all morning. Add message Save Share Report Bookmark"],
#   ['DadDadDad',
#    '19/11/2022',
#    '11:57',
#    'Drywhitefruitycidergin · 19/11/2022 11:23 ⏱️ I just completed PlusWord in 15:30 www.telegraph.co.uk/plusword/ I went through 3 PMs before I got here! Going through 3 PMs in a short space of time is all the rage these days! Add message Save Share Report Bookmark'],
#   ['AngeloMysterioso',
#    '19/11/2022',
#    '11:59',
#    '⏱️ I just completed PlusWord in 04:17 I can live with that. 1A threw me for a little while there. Also again caught out by the clock starting while the pop up puzzle page was up Add message Save Share Report Bookmark'],
#   ['Wattleanddaub',
#    '19/11/2022',
#    '13:05',
#    "Today's was so frustrating I nearly packed it in. 1a and 3d particularly Add message Save Share Report Bookmark"],
#   ['BrilliantGreenFlamingo',
#    '19/11/2022',
#    '13:25',
#    'Thanks marmite. I did it in the end. Took 20 mins! I hadn’t heard of 8A. Add message Save Share Report Bookmark'],
#   ['hoochyhag',
#    '19/11/2022',
#    '17:22',
#    'Oh dear 😂 ⏱️ I just completed PlusWord in 26:10 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark'],
#   ['hoochyhag',
#    '19/11/2022',
#    '17:23',
#    'Yes! 1a I blame it all on this 🙄 Add message Save Share Report Bookmark'],
#   ['TwinklingStarlight',
#    '19/11/2022',
#    '18:59',
#    "1A took me ages, but I found today's enjoyably hard rather than annoyingly impossible. Add message Save Share Report Bookmark"],
#   ['Sunbird24',
#    '20/11/2022',
#    '00:16',
#    '⏱️ I just completed PlusWord in 00:49 I disagree with the spelling of 3D! Am ok with everything else though. PW not too bad, at least there’s a green letter today Add message Save Share Report Bookmark'],
#   ['Floralnomad',
#    '20/11/2022',
#    '01:15',
#    '01:27 so about usual for me Add message Save Share Report Bookmark'],
#   ['JoyDivisionOvenGlovesx',
#    '20/11/2022',
#    '07:10',
#    '⏱️ I just completed PlusWord in 0:55 Luckily didn’t need 3D, but if I did, I’d be stuck as never seen it spelt like that. Add message Save Share Report Bookmark'],
#   ['sanityisamyth',
#    '20/11/2022',
#    '07:59',
#    '3.22 for me. Woeful! WFT is 3D?! Add message Save Share Report Bookmark'],
#   ['Readytostartagain',
#    '20/11/2022',
#    '08:21',
#    '⏱️ I just completed PlusWord in 02:16 Started off wrong but once I got on track it was ok Add message Save Share Report Bookmark'],
#   ['SquirrelFan',
#    '20/11/2022',
#    '08:25',
#    '⏱️ I just completed PlusWord in 01:04! My fastest time ever! (Been too embarrassed to share my times!) Add message Save Share Report Bookmark'],
#   ['Swissnotswiss',
#    '20/11/2022',
#    '08:25',
#    "⏱️ I just completed PlusWord in 04:35 www.telegraph.co.uk/plusword/ Could be worse - I didn't get anything for the first minute. Add message Save Share Report Bookmark"],
#   ['Swissnotswiss',
#    '20/11/2022',
#    '08:26',
#    'Well done @SquirrelFan ! Add message Save Share Report Bookmark'],
#   ['DadDadDad',
#    '20/11/2022',
#    '08:37',
#    "I'm like you, @Swissnotswiss - took a while to find a way in. 4:15 for me. @Sunbird24 - not the spelling I would give for 3D but it does seem to be well-established in online dictionaries. Add message Save Share Report Bookmark"],
#   ['UmbilicusProfundus',
#    '20/11/2022',
#    '08:39',
#    'I’m too ashamed to disclose my time today. Add message Save Share Report Bookmark'],
#   ['oviraptor21',
#    '20/11/2022',
#    '08:59',
#    '⏱️ I just completed PlusWord in 01:15 www.telegraph.co.uk/plusword/ Also disagree with 3d. Add message Save Share Report Bookmark'],
#   ['LikeTearsInRain',
#    '20/11/2022',
#    '09:20',
#    '⏱️ I just completed PlusWord in 07:19 finding then harder lately, more vague clues or niche things I have never heard of e.g. I’ve never heard of the word chalcedony before and the weird cricket byes one the other day Add message Save Share Report Bookmark'],
#   ['MarmiteWine',
#    '20/11/2022',
#    '10:48',
#    '⏱️ I just completed PlusWord in 05:37 www.telegraph.co.uk/plusword/ Completely thrown off by 3D! Add message Save Share Report Bookmark'],
#   ['Mumsnut',
#    '20/11/2022',
#    '11:31',
#    '6.55 Add message Save Share Report Bookmark'],
#   ['hoochyhag',
#    '20/11/2022',
#    '17:04',
#    'Woo hoo, amazing for me. ⏱️ I just completed PlusWord in 05:13 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark'],
#   ['hoochyhag',
#    '20/11/2022',
#    '17:06',
#    'Yes 3d was contrived 🙄 Add message Save Share Report Bookmark'],
#   ['Drywhitefruitycidergin',
#    '20/11/2022',
#    '17:18',
#    '⏱️ I just completed PlusWord in 05:34 www.telegraph.co.uk/plusword/ Had to google to get going though! Nice pw Add message Save Share Report Bookmark'],
#   ['Hepzibar',
#    '20/11/2022',
#    '18:29',
#    'Had to leave it and come back, ⏱️ I just completed PlusWord in 03:14 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark'],
#   ['bruffin',
#    '21/11/2022',
#    '00:10',
#    '⏱️ I just completed PlusWord in 02:25 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark'],
#   ['LikeTearsInRain',
#    '21/11/2022',
#    '00:22',
#    '⏱️ I just completed PlusWord in 04:02 Add message Save Share Report Bookmark'],
#   ['Floralnomad',
#    '21/11/2022',
#    '01:08',
#    '02:00 so not too bad Add message Save Share Report Bookmark'],
#   ['Hepzibar',
#    '21/11/2022',
#    '06:13',
#    'Not too bad ⏱️ I just completed PlusWord in 02:50 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark'],
#   ['Sunbird24',
#    '21/11/2022',
#    '07:06',
#    '⏱️ I just completed PlusWord in 01:04 Couldn’t just whizz through in order, but nothing really obscure today. Add message Save Share Report Bookmark'],
#   ['DadDadDad',
#    '21/11/2022',
#    '07:26',
#    '2:08 today. Nothing too tricky there. Add message Save Share Report Bookmark'],
#   ['JoyDivisionOvenGlovesx',
#    '21/11/2022',
#    '07:39',
#    '⏱️ I just completed PlusWord in 01:43 Went a bit wonky at first, but got myself back. Add message Save Share Report Bookmark'],
#   ['Readytostartagain',
#    '21/11/2022',
#    '08:23',
#    '2:49 fir me due to typos Add message Save Share Report Bookmark'],
#   ['oviraptor21',
#    '21/11/2022',
#    '08:28',
#    'Slow - preferred a different answer for 4d! ⏱️ I just completed PlusWord in 02:52 www.telegraph.co.uk/plusword/ Record time on crosswordle though! Daily Crosswordle 306: 26s crosswordle.vercel.app/?daily=1 ⬜⬜🟨⬜⬜ 🟨⬜🟨⬜⬜ ⬜🟨⬜🟩🟨 🟩🟩🟩🟩🟩 Add message Save Share Report Bookmark'],
#   ['AngeloMysterioso',
#    '21/11/2022',
#    '11:37',
#    '⏱️ I just completed PlusWord in 01:59 Add message Save Share Report Bookmark'],
#   ['Mumsnut',
#    '21/11/2022',
#    '14:13',
#    'Much better. Not divulging my time though ;) Add message Save Share Report Bookmark'],
#   ['Sunbird24',
#    '21/11/2022',
#    '17:08',
#    'Is anyone else playing xordle? You have one grid, but there are two words in it so you can have two letters go green in the same spot. You get a starter word as well which tends to be related to the words you’re looking for in the grid - my favourite so far had DRYER to start and the words were WHERE and SOCKS! 😂 Add message Save Share Report Bookmark'],
#   ['hoochyhag',
#    '21/11/2022',
#    '17:16',
#    'Behind a paywall now? Add message Save Share Report Bookmark'],
#   ['MarmiteWine',
#    '21/11/2022',
#    '19:49',
#    "⏱️ I just completed PlusWord in 00:55 www.telegraph.co.uk/plusword/ Nothing controversial today, but didn't immediately spot 6A or 8A Add message Save Share Report Bookmark"],
#   ['Drywhitefruitycidergin',
#    '22/11/2022',
#    '00:25',
#    '⏱️ I just completed PlusWord in 02:19 www.telegraph.co.uk/plusword/ Should have been even quicker. I had a typo which took me ages to notice Add message Save Share Report Bookmark'],
#   ['Welshwabbit',
#    '22/11/2022',
#    '00:45',
#    "⏱️ I just completed PlusWord in 01:16 www.telegraph.co.uk/plusword/ I think that's my best time. I'm not very fast! Add message Save Share Report Bookmark"],
#   ['Hepzibar',
#    '22/11/2022',
#    '06:12',
#    'Good time for me and a bit easier today - possibly the first time I have actually heard all of the words 🙄 Imagine there will be some very quick times today ⏱️ I just completed PlusWord in 01:55 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark'],
#   ['Sunbird24',
#    '22/11/2022',
#    '06:52',
#    '⏱️ I just completed PlusWord in 01:01 I had typing issues today so also expect faster times! Add message Save Share Report Bookmark'],
#   ['DadDadDad',
#    '22/11/2022',
#    '07:12',
#    'My plodding time was 2:20 today. Add message Save Share Report Bookmark'],
#   ['oviraptor21',
#    '22/11/2022',
#    '07:15',
#    '⏱️ I just completed PlusWord in 01:18 www.telegraph.co.uk/plusword/ Should have been quicker as all the words came immediately, I was just slow typing. Add message Save Share Report Bookmark'],
#   ['Readytostartagain',
#    '22/11/2022',
#    '07:26',
#    '⏱️ I just completed PlusWord in 01:04 Straightforward today Add message Save Share Report Bookmark'],
#   ['JoyDivisionOvenGlovesx',
#    '22/11/2022',
#    '07:32',
#    '⏱️ I just completed PlusWord in 00:50 A nice one today. Add message Save Share Report Bookmark'],
#   ['Mumsnut',
#    '22/11/2022',
#    '07:34',
#    '1.44 Add message Save Share Report Bookmark'],
#   ['sanityisamyth',
#    '22/11/2022',
#    '08:52',
#    '00:54s!! Yippee!! Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '22/11/2022',
#    '12:23',
#    '7 mins. 6 mins of that was on the PW. Add message Save Share Report Bookmark'],
#   ['AngeloMysterioso',
#    '22/11/2022',
#    '12:35',
#    '⏱️ I just completed PlusWord in 01:24 I could’ve been a bit quicker… I’m very tired 🥱 Add message Save Share Report Bookmark'],
#   ['Floralnomad',
#    '22/11/2022',
#    '13:40',
#    "I just completed today's PlusWord in 01:05 , nice one today . Add message Save Share Report Bookmark"],
#   ['hoochyhag',
#    '22/11/2022',
#    '15:07',
#    "Oh no \U0001fae2 ⏱️ I just completed PlusWord in 19:57 www.telegraph.co.uk/plusword/ I didn't realise that other letters could be used that were not in the shaded squares. Saying that, I am now well and truly addicted ☺️ Add message Save Share Report Bookmark"],
#   ['hoochyhag',
#    '22/11/2022',
#    '15:10',
#    "I think I'm in the plus word group that need 'additional support' 🙄 Add message Save Share Report Bookmark"],
#   ['UmbilicusProfundus',
#    '22/11/2022',
#    '17:57',
#    '⏱️ I just completed PlusWord in 00:49 Back on form for me today after a prolonged period in the doldrums. First time in a while to get consecutive guesses right first time (and no weird words) Add message Save Share Report Bookmark'],
#   ['Sunbird24',
#    '22/11/2022',
#    '18:35',
#    '@hoochyhag don’t worry, you’ll get faster! Add message Save Share Report Bookmark'],
#   ['MarmiteWine',
#    '22/11/2022',
#    '21:08',
#    '⏱️ I just completed PlusWord in 00:50 www.telegraph.co.uk/plusword/ Happy with that, considering typos! Add message Save Share Report Bookmark'],
#   ['Drywhitefruitycidergin',
#    '23/11/2022',
#    '00:35',
#    '⏱️ I just completed PlusWord in 02:33 www.telegraph.co.uk/plusword/ Made unnecessarily hard work of that because I knew all the words and only had a couple of changes where my first go was wrong. Expect some fast times today! Add message Save Share Report Bookmark'],
#   ['Floralnomad',
#    '23/11/2022',
#    '01:52',
#    'I just completed PlusWord in 00:49 , which I think is a record for me 😀 Add message Save Share Report Bookmark'],
#   ['Hepzibar',
#    '23/11/2022',
#    '06:43',
#    'Impressive @Floralnomad and agree @Drywhitefruitycidergin there will be some fast times today. It was relatively easy (compared to some stinkers recently) This is a good time for me (plodder) ⏱️ I just completed PlusWord in 02:30 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark'],
#   ['JoyDivisionOvenGlovesx',
#    '23/11/2022',
#    '07:08',
#    '⏱️ I just completed PlusWord in 00:50 Yep, quite straightforward. Add message Save Share Report Bookmark'],
#   ['oviraptor21',
#    '23/11/2022',
#    '07:10',
#    '⏱️ I just completed PlusWord in 01:28 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark'],
#   ['DadDadDad',
#    '23/11/2022',
#    '07:14',
#    '1:55 for me. Always happy with sub-2 min Add message Save Share Report Bookmark'],
#   ['Readytostartagain',
#    '23/11/2022',
#    '08:38',
#    '⏱️ I just completed PlusWord in 01:16 Happy with that 😃 Add message Save Share Report Bookmark'],
#   ['Floralnomad',
#    '23/11/2022',
#    '10:42',
#    'The only reason I got that time was because I just went straight across the down clues , normally I get slowed up by over typing when I’m switching around on the clues . It will likely never happen again . Add message Save Share Report Bookmark'],
#   ['Swissnotswiss',
#    '23/11/2022',
#    '12:47',
#    '1:25 today. Easy for me but still way off the minute mark! Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '23/11/2022',
#    '12:55',
#    'Nearly 4 mins. Got stuck on the PW for a while. Add message Save Share Report Bookmark'],
#   ['hoochyhag',
#    '23/11/2022',
#    '16:39',
#    'Gah! Was doing it well, then got the plus word mixed up. Just looked up one of the clues. I love this. ⏱️ I just completed PlusWord in 10:17 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark'],
#   ['hoochyhag',
#    '23/11/2022',
#    '16:41',
#    'Oh some brilliant times on here today Add message Save Share Report Bookmark'],
#   ['MarmiteWine',
#    '23/11/2022',
#    '18:03',
#    '⏱️ I just completed PlusWord in 01:11 www.telegraph.co.uk/plusword/ CW nice and easy, PW took a little thought Add message Save Share Report Bookmark'],
#   ['Sunbird24',
#    '23/11/2022',
#    '19:16',
#    '⏱️ I just completed PlusWord in 00:48 Was without my phone for a lot of today as it had to go and have a new battery fitted! (Lots cheaper than getting a new phone though…) Add message Save Share Report Bookmark'],
#   ['Drywhitefruitycidergin',
#    '23/11/2022',
#    '20:22',
#    "I agree @BrilliantGreenFlamingo - I've got into a habit of doing wordle, waffle, metrodle, plusword before I go to sleep. Then I wish I could do them again in the morning... Add message Save Share Report Bookmark"],
#   ['TwinklingStarlight',
#    '23/11/2022',
#    '20:36',
#    "@Drywhitefruitycidergin ah that's so annoying, then you have to skip a day to get back on track and that's hard! I like globle, worldle, plusword and waffle. Haven't tried metrodle, I will look that one up. Add message Save Share Report Bookmark"],
#   ['BrilliantGreenFlamingo',
#    '23/11/2022',
#    '21:01',
#    'I’ll look those up. I don’t do wordle anymore coz I find it boring compared with this. I tried redactle but got in a right piss about it. Particularly coz it took me hundreds of guesses to get it and loads of people on here got it in ONE! I tried it again a few weeks later and it was some random scientific word I didn’t know. Add message Save Share Report Bookmark'],
#   ['JoyDivisionOvenGlovesx',
#    '23/11/2022',
#    '21:03',
#    'I’m a stupidly early riser, and like to do all* before I get out of bed. If anyone is interested, I do: Wordle Byrdle Worldle Heardle (x 6, includes decades versions) Squareword Waffle Wordall Mathler Susie Squaredle And of course, our beloved PW! I think my favourites are Susie, Wordall & Squaredle *Squaredle updates at 11am, so often save that one for lunchtime or later! Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '23/11/2022',
#    '21:11',
#    'Thanks! I’ll check them out too. I need another puzzle. Add message Save Share Report Bookmark'],
#   ['Sunbird24',
#    '23/11/2022',
#    '21:39',
#    '@JoyDivisionOvenGlovesx try Xordle! Add message Save Share Report Bookmark'],
#   ['Drywhitefruitycidergin',
#    '23/11/2022',
#    '22:34',
#    "@TwinklingStarlight metrodle's very niche. If you are London based or know tube map well it's awesome. Otherwise....maybe try some of @JoyDivisionOvenGlovesx choices. Add message Save Share Report Bookmark"],
#   ['AngeloMysterioso',
#    '23/11/2022',
#    '23:53',
#    'Did alright today! ⏱️ I just completed PlusWord in 01:51 Add message Save Share Report Bookmark'],
#   ['LikeTearsInRain',
#    '24/11/2022',
#    '00:11',
#    '⏱️ I just completed PlusWord in 03:29 Add message Save Share Report Bookmark'],
#   ['Floralnomad',
#    '24/11/2022',
#    '00:54',
#    '01:05 , another nice one Add message Save Share Report Bookmark'],
#   ['Sunbird24',
#    '24/11/2022',
#    '03:53',
#    '⏱️ I just completed PlusWord in 00:55 Add message Save Share Report Bookmark'],
#   ['Hepzibar',
#    '24/11/2022',
#    '06:23',
#    '⏱️ I just completed PlusWord in 03:08 www.telegraph.co.uk/plusword/ Add message Save Share Report Bookmark'],
#   ['oviraptor21',
#    '24/11/2022',
#    '07:04',
#    '⏱️ I just completed PlusWord in 01:26 www.telegraph.co.uk/plusword/ An incorrect pw slowed me down. Add message Save Share Report Bookmark'],
#   ['DadDadDad',
#    '24/11/2022',
#    '07:11',
#    '1:46 today. Add message Save Share Report Bookmark'],
#   ['Welshwabbit',
#    '24/11/2022',
#    '07:47',
#    '1.27 which is good for me! Add message Save Share Report Bookmark'],
#   ['UmbilicusProfundus',
#    '24/11/2022',
#    '07:49',
#    '⏱️ I just completed PlusWord in 01:23 Add message Save Share Report Bookmark'],
#   ['Drywhitefruitycidergin',
#    '24/11/2022',
#    '08:24',
#    "⏱️ I just completed PlusWord in 01:01 www.telegraph.co.uk/plusword/ Nearly made the sub 1m - I think that's a record for me! Add message Save Share Report Bookmark"],
#   ['JoyDivisionOvenGlovesx',
#    '24/11/2022',
#    '08:38',
#    '⏱️ I just completed PlusWord in 00:49 Nice ‘n simple today. Thanks for recommendation @Sunbird24. A few others have been dropped from my list, but never tried Xordle so I may just give it a go. Add message Save Share Report Bookmark'],
#   ['Readytostartagain',
#    '24/11/2022',
#    '08:57',
#    '⏱️ I just completed PlusWord in 00:40 Nice one today Add message Save Share Report Bookmark'],
#   ['BrilliantGreenFlamingo',
#    '24/11/2022',
#    '18:27',
#    '3:02 today. Not super speedy but ok! Add message Save Share Report Bookmark'],
#   ['MarmiteWine',
#    '24/11/2022',
#    '18:33',
#    "⏱️ I just completed PlusWord in 00:58 www.telegraph.co.uk/plusword/ Thanks for the xordle recommendation @Sunbird24 I've been playing for a couple of days now. Add message Save Share Report Bookmark"],
#   ['Sunbird24',
#    '25/11/2022',
#    '04:34',
#    '⏱️ I just completed PlusWord in 00:56 CW is pretty nice but they’ve been stingy with the letters for the PW! Add message Save Share Report Bookmark'],
#   ['JoyDivisionOvenGlovesx',
#    '25/11/2022',
#    '06:05',
#    '⏱️ I just completed PlusWord in 01:02 Took a bit longer than I’d have liked to see the darn PW. Add message Save Share Report Bookmark']]]

# %%
df = pd.DataFrame(result_list, columns=['user', 'date', 'time', 'text'])
        
modified_end = time.time()
modified_time = modified_end - modified_start
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in _finalize_columns_and_data(content, columns, dtype)
#     968     try:
# --> 969         columns = _validate_or_indexify_columns(contents, columns)
#     970     except AssertionError as err:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#    1016             # caller's responsibility to check for this...
# -> 1017             raise AssertionError(
#    1018                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 4 columns passed, passed data had 204 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_11417/1311765506.py in <module>
# ----> 1 df = pd.DataFrame(result_list, columns=['user', 'date', 'time', 'text'])
#       2
#       3 modified_end = time.time()
#       4 modified_time = modified_end - modified_start
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     744                     if columns is not None:
#     745                         columns = ensure_index(columns)
# --> 746                     arrays, columns, index = nested_data_to_arrays(
#     747                         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     748                         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in nested_data_to_arrays(data, columns, index, dtype)
#     508         columns = ensure_index(data[0]._fields)
#     509
# --> 510     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     511     columns = ensure_index(columns)
#     512
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, dtype)
#     873         arr = _list_to_arrays(data)
#     874
# --> 875     content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     876     return content, columns
#     877
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in _finalize_columns_and_data(content, columns, dtype)
#     970     except AssertionError as err:
#     971         # GH#26429 do not raise user-facing AssertionError
# --> 972         raise ValueError(err) from err
#     973
#     974     if len(contents) and contents[0].dtype == np.object_:
#
# ValueError: 4 columns passed, passed data had 204 columns

# %%
df
